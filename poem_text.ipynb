# %%
import pandas as pd
from tqdm import tqdm, trange

text = pd.read_csv("text.csv")

# %%
text.head()
# Out:
#    vol  page line                      text
# 0  V01  P001  L00                        桐壺
# 1  V01  P001  L01    いづれの御時にか女御更衣あまたさふらひ給ける
# 2  V01  P001  L02     なかに。いとやむごとなききはにはあらぬが。
# 3  V01  P001  L03     すぐれてときめき給ふありけりはじめよりわれ
# 4  V01  P001  L04  はと思ひあがり給へる御かた＋＋＄。めざましきもの

# %%
poem_list = []

# %%
for i in tqdm(range(len(text))):    
    if (str(text.iloc[i,3])[0:2] == '△△'):
        poem_list.append(True)
    else:
        poem_list.append(False)
# Out:
# 100%|██████████| 79714/79714 [00:00<00:00, 104556.02it/s]

# %%
j = 0
while j < len(poem_list):
    if (poem_list[j]):
        poem_list[j + 1] = True
        j += 2
    else:
        j += 1

# %%
text['is_poem'] = poem_list

# %%
text.to_csv('text_poem.csv')

# %%
text.head()
# Out:
#                        text  is_poem
# 0                        桐壺    False
# 1    いづれの御時にか女御更衣あまたさふらひ給ける    False
# 2     なかに。いとやむごとなききはにはあらぬが。    False
# 3     すぐれてときめき給ふありけりはじめよりわれ    False
# 4  はと思ひあがり給へる御かた＋＋＄。めざましきもの    False

# %%
#drop column
text.drop(['vol', 'page', 'line'], axis=1, inplace = True)

# %%
poem = pd.DataFrame()

# %%
poem = text[text['is_poem'] == True]

# %%
poem.head()
# Out:
#                        text  is_poem
# 99    △△かぎりとてわかるゝ道のかなしきにいかま     True
# 100   ほしきは命成けりいとかく思ふ給へましかばと     True
# 194   △△みやぎのゝつゆふきむすぶ風のをとに小萩     True
# 195  がもとを思ひこそやれとあれどえ見給はてずいの     True
# 242   △△すゞ虫のこゑのかぎりをつくしてもながき     True

# %%
poem.drop(['is_poem'], axis = 1, inplace = True)
# Out:
# /home/tarin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
poem.to_csv('')
# Out:
#                                   text
# 99               △△かぎりとてわかるゝ道のかなしきにいかま
# 100              ほしきは命成けりいとかく思ふ給へましかばと
# 194              △△みやぎのゝつゆふきむすぶ風のをとに小萩
# 195             がもとを思ひこそやれとあれどえ見給はてずいの
# 242              △△すゞ虫のこゑのかぎりをつくしてもながき
# 243                 夜あかずふるなみだかなえものりやらず
# 244              △△いとゞしく虫のねしげきあさぢふに露をき
# 245            そふる雲のうへ人かごとも聞えつべくなんといはせ
# 268              △△あらき風ふせぎしかげのかれしよりこはぎ
# 269             がうへぞしづ心なき。などやうにみだりがはしき
# 285               △△尋ね行まぼろしもがなつてにても玉のあ
# 286             りかをそことしるべくゑにかける楊貴妃のかたち
# 303             △△雲のうへもなみだにくるゝ秋の月いかですむ
# 304              覧あさぢふの宿おぼしやりつゝともし火をかゝ
